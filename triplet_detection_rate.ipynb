# %%
import data_io
from numpy import *
from classes.block import Block
from classes.triplet import Triplet
from classes.shot import Shot
import re
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

data_io.loadAll("data")
# Out:
# Loading 2013AE.json
# Loading 2013AO.json
# Loading 2013BL.json
# Loading 2014BH.json
# Loading 2015AM.json
# Loading 2015AP.json
# Loading 2015BC.json
# Loading 2015BD.json
# Loading 2015BS.json
# Loading 2015BT.json

# %%
import interface

for _, triplet in Triplet.all.items():
    interface.loadTriplet(triplet)
    if triplet.rates != []:
        plt.figure()
        for rate in triplet.rates:
            if rate.func == "tan":    plt.plot(m,ft(m,rate.a,rate.b,rate.c,rate.d),label="tan")
            if rate.func == "square": plt.plot(m,fs(m,rate.a,rate.b,rate.c,rate.d),label="square")
        plt.title(f"Block {triplet.block.id}, Triplet {triplet.id}")
        plt.legend()
        plt.grid()

data_io.saveAll(indent=4)
# Out:
# C:\Users\vince\AppData\Local\Temp\ipykernel_9760\2602638101.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
